# %%
import pandas as pd
import os

from IPython.display import display

# %%
pd.options.display.max_rows = 999
pd.options.display.max_colwidth = 999
pd.options.display.max_columns = 999
pd.options.display.float_format = '{:.3f}'.format

# %%
properties = [
    'pH',
    'OM',
    'Ca',
    'Mg',
    'K',
    'Na'
]

models = [
    'LR',
    'SVR',
    'LASSO',
    'PLSR2',
    'PLSR6',
    'RF'
]

scalers = [
#     'wo_norm',
    'minmax',
    'standard'
]

satellites = [
    'landsat_simulated',
    'landsat_simulated_indices',
    'sentinel2_simulated',
    'sentinel2_simulated_indices',
    'desis_simulated',
    'sentinel2_soil',
    'sentinel2_soil_indices',
    'sentinel2_all',
    'sentinel2_all_indices',
#     'vis_nir'
]

transformations = [
    'scE_d1_d2_',
    'scE_d1_d2_fft_',
    'scE_d1_d2_cr_',
    'scE_d1_d2_fft_cr_'
]

# %%
all_satelital_metrics_data = []

for satellite in satellites:
    for scaler in scalers:
        for transformation in transformations:
            for property_ in properties:
                path = (
                    f'../data/models/predictions/{satellite}/{scaler}/' +
                    f'{transformation}/{property_}/metrics.csv'
                )
                df_metrics = pd.read_csv(path, sep=';', decimal='.')
                all_satelital_metrics_data.append(df_metrics)
                
#                 temp = []
#                 for path in files_paths:
#                     metrics_path_ = os.path.abspath(f'../data/satellite_data/{satellite}/results/{path}') 
#                     temp.append(pd.read_csv(metrics_path_, sep=';', decimal='.'))
#                 temp_ = pd.concat(temp)
#

# %%
all_metrics = pd.concat(all_satelital_metrics_data)

# %%
print(all_metrics.shape)
all_metrics.head()
# Out:
# (2592, 16)
#            Satellite  Scaler    Features Property  Model  CC Train All  \
# 0  landsat_simulated  minmax  scE_d1_d2_       pH     LR         0.776
# 1  landsat_simulated  minmax  scE_d1_d2_       pH    SVR         0.764
# 2  landsat_simulated  minmax  scE_d1_d2_       pH  LASSO         0.775
# 3  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR2         0.672
# 4  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR6         0.766
#
#    CC Test All  MSE Train All  MSE CV All  MSE Test All  R2 Train All  \
# 0        0.804          0.536       0.595         0.618         0.602
# 1        0.776          0.562       0.625         0.674         0.582
# 2        0.798          0.537       0.607         0.632         0.601
# 3        0.677          0.739       0.796         0.910         0.451
# 4        0.786          0.557       0.602         0.656         0.586
#
#    R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0      0.533        0.631         0.602      0.559        0.635
# 1      0.507        0.598         0.582      0.532        0.599
# 2      0.524        0.623         0.601      0.552        0.627
# 3      0.368        0.457         0.451      0.396        0.457
# 4      0.526        0.609         0.586      0.552        0.611

# %%
all_metrics.groupby('Satellite').count()
# Out:
#                              Scaler  Features  Property  Model  CC Train All  \
# Satellite
# desis_simulated                 288       288       288    288           288
# landsat_simulated               288       288       288    288           288
# landsat_simulated_indices       288       288       288    288           288
# sentinel2_all                   288       288       288    288           284
# sentinel2_all_indices           288       288       288    288           284
# sentinel2_simulated             288       288       288    288           288
# sentinel2_simulated_indices     288       288       288    288           288
# sentinel2_soil                  288       288       288    288           274
# sentinel2_soil_indices          288       288       288    288           274
#
#                              CC Test All  MSE Train All  MSE CV All  \
# Satellite
# desis_simulated                      288            288         288
# landsat_simulated                    288            288         288
# landsat_simulated_indices            288            288         288
# sentinel2_all                        284            288         288
# sentinel2_all_indices                284            288         288
# sentinel2_simulated                  288            288         288
# sentinel2_simulated_indices          288            288         288
# sentinel2_soil                       270            288         288
# sentinel2_soil_indices               270            288         288
#
#                              MSE Test All  R2 Train All  R2 CV All  \
# Satellite
# desis_simulated                       288           288        288
# landsat_simulated                     288           288        288
# landsat_simulated_indices             288           288        288
# sentinel2_all                         288           288        288
# sentinel2_all_indices                 288           288        288
# sentinel2_simulated                   288           288        288
# sentinel2_simulated_indices           288           288        288
# sentinel2_soil                        288           288        288
# sentinel2_soil_indices                288           288        288
#
#                              R2 Test All  EV Train All  EV CV All  EV Test All
# Satellite
# desis_simulated                      288           288        288          288
# landsat_simulated                    288           288        288          288
# landsat_simulated_indices            288           288        288          288
# sentinel2_all                        288           288        288          288
# sentinel2_all_indices                288           288        288          288
# sentinel2_simulated                  288           288        288          288
# sentinel2_simulated_indices          288           288        288          288
# sentinel2_soil                       288           288        288          288
# sentinel2_soil_indices               288           288        288          288

# %% [markdown]
# ## All result data

# %%
print(all_metrics.shape)
all_metrics.head()
# Out:
# (2592, 16)
#            Satellite  Scaler    Features Property  Model  CC Train All  \
# 0  landsat_simulated  minmax  scE_d1_d2_       pH     LR         0.776
# 1  landsat_simulated  minmax  scE_d1_d2_       pH    SVR         0.764
# 2  landsat_simulated  minmax  scE_d1_d2_       pH  LASSO         0.775
# 3  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR2         0.672
# 4  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR6         0.766
#
#    CC Test All  MSE Train All  MSE CV All  MSE Test All  R2 Train All  \
# 0        0.804          0.536       0.595         0.618         0.602
# 1        0.776          0.562       0.625         0.674         0.582
# 2        0.798          0.537       0.607         0.632         0.601
# 3        0.677          0.739       0.796         0.910         0.451
# 4        0.786          0.557       0.602         0.656         0.586
#
#    R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0      0.533        0.631         0.602      0.559        0.635
# 1      0.507        0.598         0.582      0.532        0.599
# 2      0.524        0.623         0.601      0.552        0.627
# 3      0.368        0.457         0.451      0.396        0.457
# 4      0.526        0.609         0.586      0.552        0.611

# %%
all_metrics['Satellite'].unique()
# Out:
# array(['landsat_simulated', 'landsat_simulated_indices',
#        'sentinel2_simulated', 'sentinel2_simulated_indices',
#        'desis_simulated', 'sentinel2_soil', 'sentinel2_soil_indices',
#        'sentinel2_all', 'sentinel2_all_indices'], dtype=object)

# %%
all_metrics[
    (all_metrics['Satellite'].isin(
#         ['sentinel2_simulated']
        ['landsat_simulated', 'landsat_simulated_indices',
       'sentinel2_simulated', 'sentinel2_simulated_indices',
       'sentinel2_soil', 'sentinel2_soil_indices',
       'sentinel2_all', 'sentinel2_all_indices']
    ))
].sort_values(
    by=['R2 CV All', 'R2 Test All'],
    ascending=False
).reset_index(drop=True).head(20)
# Out:
#                       Satellite    Scaler           Features Property  Model  \
# 0           sentinel2_simulated  standard         scE_d1_d2_       pH    SVR
# 1           sentinel2_simulated  standard     scE_d1_d2_fft_       pH    SVR
# 2   sentinel2_simulated_indices  standard         scE_d1_d2_       pH    SVR
# 3   sentinel2_simulated_indices  standard     scE_d1_d2_fft_       pH    SVR
# 4           sentinel2_simulated    minmax         scE_d1_d2_       pH  PLSR6
# 5           sentinel2_simulated  standard         scE_d1_d2_       pH  PLSR6
# 6   sentinel2_simulated_indices    minmax         scE_d1_d2_       pH  PLSR6
# 7   sentinel2_simulated_indices  standard         scE_d1_d2_       pH  PLSR6
# 8           sentinel2_simulated    minmax         scE_d1_d2_       pH    SVR
# 9           sentinel2_simulated    minmax     scE_d1_d2_fft_       pH    SVR
# 10  sentinel2_simulated_indices    minmax         scE_d1_d2_       pH    SVR
# 11  sentinel2_simulated_indices    minmax     scE_d1_d2_fft_       pH    SVR
# 12          sentinel2_simulated    minmax         scE_d1_d2_       pH     RF
# 13          sentinel2_simulated    minmax      scE_d1_d2_cr_       pH    SVR
# 14          sentinel2_simulated    minmax  scE_d1_d2_fft_cr_       pH    SVR
# 15  sentinel2_simulated_indices    minmax      scE_d1_d2_cr_       pH    SVR
# 16  sentinel2_simulated_indices    minmax  scE_d1_d2_fft_cr_       pH    SVR
# 17  sentinel2_simulated_indices  standard         scE_d1_d2_       pH     RF
# 18          sentinel2_simulated  standard     scE_d1_d2_fft_       pH     LR
# 19  sentinel2_simulated_indices  standard     scE_d1_d2_fft_       pH     LR
#
#     CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0          0.841        0.859          0.395       0.443         0.452
# 1          0.841        0.859          0.395       0.443         0.452
# 2          0.841        0.859          0.395       0.443         0.452
# 3          0.841        0.859          0.395       0.443         0.452
# 4          0.832        0.858          0.413       0.459         0.474
# 5          0.832        0.858          0.413       0.459         0.474
# 6          0.832        0.858          0.413       0.459         0.474
# 7          0.832        0.858          0.413       0.459         0.474
# 8          0.832        0.860          0.415       0.476         0.462
# 9          0.832        0.860          0.415       0.477         0.462
# 10         0.832        0.860          0.415       0.476         0.462
# 11         0.832        0.860          0.415       0.477         0.462
# 12         0.897        0.856          0.271       0.493         0.469
# 13         0.834        0.852          0.410       0.478         0.472
# 14         0.834        0.852          0.410       0.478         0.472
# 15         0.834        0.852          0.410       0.478         0.472
# 16         0.834        0.852          0.410       0.478         0.472
# 17         0.898        0.858          0.268       0.513         0.468
# 18         0.847        0.855          0.381       0.499         0.459
# 19         0.847        0.855          0.381       0.499         0.459
#
#     R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0          0.707      0.638        0.730         0.707      0.650        0.732
# 1          0.707      0.638        0.730         0.707      0.650        0.732
# 2          0.707      0.638        0.730         0.707      0.650        0.732
# 3          0.707      0.638        0.730         0.707      0.650        0.732
# 4          0.693      0.626        0.717         0.693      0.642        0.719
# 5          0.693      0.626        0.717         0.693      0.642        0.719
# 6          0.693      0.626        0.717         0.693      0.642        0.719
# 7          0.693      0.626        0.717         0.693      0.642        0.719
# 8          0.692      0.618        0.724         0.692      0.641        0.726
# 9          0.692      0.618        0.724         0.692      0.641        0.726
# 10         0.692      0.618        0.724         0.692      0.641        0.726
# 11         0.692      0.618        0.724         0.692      0.641        0.726
# 12         0.799      0.616        0.720         0.799      0.648        0.721
# 13         0.695      0.614        0.718         0.696      0.635        0.719
# 14         0.695      0.614        0.718         0.696      0.635        0.719
# 15         0.695      0.614        0.718         0.696      0.635        0.719
# 16         0.695      0.614        0.718         0.696      0.635        0.719
# 17         0.801      0.603        0.721         0.801      0.643        0.722
# 18         0.717      0.602        0.726         0.717      0.639        0.727
# 19         0.717      0.602        0.726         0.717      0.639        0.727

# %%
all_metrics[~all_metrics['Satellite'].isin(['vis_nir', 'desis_simulated'])].sort_values(
    by=['R2 CV All', 'R2 Test All'],
    ascending=False
).tail(50)
# Out:
#                  Satellite    Scaler           Features Property  Model  \
# 4  sentinel2_veggi_indices    minmax         scE_d1_d2_       Ca  PLSR6
# 4  sentinel2_veggi_indices  standard         scE_d1_d2_       Ca  PLSR6
# 0          sentinel2_veggi   wo_norm         scE_d1_d2_       Ca     LR
# 0  sentinel2_veggi_indices   wo_norm         scE_d1_d2_       Ca     LR
# 1          sentinel2_veggi  standard         scE_d1_d2_       Ca    SVR
# 1  sentinel2_veggi_indices  standard         scE_d1_d2_       Ca    SVR
# 1          sentinel2_veggi  standard     scE_d1_d2_fft_       Ca    SVR
# 1  sentinel2_veggi_indices  standard     scE_d1_d2_fft_       Ca    SVR
# 0          sentinel2_veggi   wo_norm  scE_d1_d2_fft_cr_       pH     LR
# 0  sentinel2_veggi_indices   wo_norm  scE_d1_d2_fft_cr_       pH     LR
# 2          sentinel2_veggi   wo_norm     scE_d1_d2_fft_       Ca  LASSO
# 2  sentinel2_veggi_indices   wo_norm     scE_d1_d2_fft_       Ca  LASSO
# 3          sentinel2_veggi   wo_norm     scE_d1_d2_fft_       Ca  PLSR2
# 3  sentinel2_veggi_indices   wo_norm     scE_d1_d2_fft_       Ca  PLSR2
# 4          sentinel2_veggi   wo_norm     scE_d1_d2_fft_       Ca  PLSR6
# 4  sentinel2_veggi_indices   wo_norm     scE_d1_d2_fft_       Ca  PLSR6
# 0          sentinel2_veggi  standard     scE_d1_d2_fft_        K     LR
# 0  sentinel2_veggi_indices  standard     scE_d1_d2_fft_        K     LR
# 0          sentinel2_veggi  standard     scE_d1_d2_fft_       Mg     LR
# 0  sentinel2_veggi_indices  standard     scE_d1_d2_fft_       Mg     LR
# 0          sentinel2_veggi    minmax     scE_d1_d2_fft_        K     LR
# 0  sentinel2_veggi_indices    minmax     scE_d1_d2_fft_        K     LR
# 0          sentinel2_veggi   wo_norm  scE_d1_d2_fft_cr_        K     LR
# 0  sentinel2_veggi_indices   wo_norm  scE_d1_d2_fft_cr_        K     LR
# 0          sentinel2_veggi    minmax     scE_d1_d2_fft_       Mg     LR
# 0  sentinel2_veggi_indices    minmax     scE_d1_d2_fft_       Mg     LR
# 0          sentinel2_veggi   wo_norm  scE_d1_d2_fft_cr_       Mg     LR
# 0  sentinel2_veggi_indices   wo_norm  scE_d1_d2_fft_cr_       Mg     LR
# 0          sentinel2_veggi  standard  scE_d1_d2_fft_cr_       Ca     LR
# 0  sentinel2_veggi_indices  standard  scE_d1_d2_fft_cr_       Ca     LR
# 0          sentinel2_veggi    minmax  scE_d1_d2_fft_cr_       Ca     LR
# 0  sentinel2_veggi_indices    minmax  scE_d1_d2_fft_cr_       Ca     LR
# 0          sentinel2_veggi   wo_norm  scE_d1_d2_fft_cr_       OM     LR
# 0  sentinel2_veggi_indices   wo_norm  scE_d1_d2_fft_cr_       OM     LR
# 0          sentinel2_veggi  standard  scE_d1_d2_fft_cr_       Mg     LR
# 0  sentinel2_veggi_indices  standard  scE_d1_d2_fft_cr_       Mg     LR
# 0          sentinel2_veggi    minmax  scE_d1_d2_fft_cr_       Mg     LR
# 0  sentinel2_veggi_indices    minmax  scE_d1_d2_fft_cr_       Mg     LR
# 0          sentinel2_veggi    minmax  scE_d1_d2_fft_cr_        K     LR
# 0  sentinel2_veggi_indices    minmax  scE_d1_d2_fft_cr_        K     LR
# 0          sentinel2_veggi    minmax  scE_d1_d2_fft_cr_       pH     LR
# 0  sentinel2_veggi_indices    minmax  scE_d1_d2_fft_cr_       pH     LR
# 0          sentinel2_veggi  standard  scE_d1_d2_fft_cr_       pH     LR
# 0  sentinel2_veggi_indices  standard  scE_d1_d2_fft_cr_       pH     LR
# 0          sentinel2_veggi  standard  scE_d1_d2_fft_cr_        K     LR
# 0  sentinel2_veggi_indices  standard  scE_d1_d2_fft_cr_        K     LR
# 0          sentinel2_veggi    minmax  scE_d1_d2_fft_cr_       OM     LR
# 0  sentinel2_veggi_indices    minmax  scE_d1_d2_fft_cr_       OM     LR
# 0          sentinel2_veggi  standard  scE_d1_d2_fft_cr_       OM     LR
# 0  sentinel2_veggi_indices  standard  scE_d1_d2_fft_cr_       OM     LR
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 4         0.664        0.664          0.062       0.269         0.062
# 4         0.664        0.664          0.559       2.413         0.559
# 0         0.684        0.684        144.628     679.407       144.628
# 0         0.684        0.684        144.628     679.407       144.628
# 1         0.657        0.657          0.598       2.697         0.598
# 1         0.657        0.657          0.598       2.697         0.598
# 1         0.657        0.657          0.598       2.704         0.598
# 1         0.657        0.657          0.598       2.704         0.598
# 0         0.788        0.788          0.690       4.280         0.690
# 0         0.788        0.788          0.690       4.280         0.690
# 2         0.379        0.379        237.204     702.406       237.204
# 2         0.379        0.379        237.204     702.406       237.204
# 3         0.454        0.454        216.008     719.713       216.008
# 3         0.454        0.454        216.008     719.713       216.008
# 4         0.656        0.656        155.105     733.144       155.105
# 4         0.656        0.656        155.105     733.144       155.105
# 0         0.509        0.509          0.809       3.740         0.809
# 0         0.509        0.509          0.809       3.740         0.809
# 0         0.500        0.500          0.754       4.420         0.754
# 0         0.500        0.500          0.754       4.420         0.754
# 0         0.602        0.602          0.013       0.095         0.013
# 0         0.602        0.602          0.013       0.095         0.013
# 0         0.671        0.671          0.006       0.050         0.006
# 0         0.671        0.671          0.006       0.050         0.006
# 0         0.524        0.524          0.024       0.168         0.024
# 0         0.524        0.524          0.024       0.168         0.024
# 0         0.637        0.637          0.131       1.480         0.131
# 0         0.637        0.637          0.131       1.480         0.131
# 0         0.805        0.805          0.353       9.716         0.353
# 0         0.805        0.805          0.353       9.716         0.353
# 0         0.801        0.801          0.040       1.122         0.040
# 0         0.801        0.801          0.040       1.122         0.040
# 0         0.555        0.555          1.490      26.724         1.490
# 0         0.555        0.555          1.490      26.724         1.490
# 0         0.679        0.679          0.538      17.450         0.538
# 0         0.679        0.679          0.538      17.450         0.538
# 0         0.676        0.676          0.018       0.556         0.018
# 0         0.676        0.676          0.018       0.556         0.018
# 0         0.670        0.670          0.011       0.236         0.011
# 0         0.670        0.670          0.011       0.236         0.011
# 0         0.790        0.790          0.042       1.416         0.042
# 0         0.790        0.790          0.042       1.416         0.042
# 0         0.794        0.794          0.370      12.821         0.370
# 0         0.794        0.794          0.370      12.821         0.370
# 0         0.691        0.691          0.523      15.133         0.523
# 0         0.691        0.691          0.523      15.133         0.523
# 0         0.566        0.566          0.022       1.187         0.022
# 0         0.566        0.566          0.022       1.187         0.022
# 0         0.571        0.571          0.674      37.519         0.674
# 0         0.571        0.571          0.674      37.519         0.674
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 4         0.441     -3.442        0.441         0.441     -2.810        0.441
# 4         0.441     -3.442        0.441         0.441     -2.810        0.441
# 0         0.468     -3.540        0.468         0.468     -3.123        0.468
# 0         0.468     -3.540        0.468         0.468     -3.123        0.468
# 1         0.402     -3.543        0.402         0.431     -3.055        0.431
# 1         0.402     -3.543        0.402         0.431     -3.055        0.431
# 1         0.402     -3.552        0.402         0.431     -3.063        0.431
# 1         0.402     -3.552        0.402         0.431     -3.063        0.431
# 0         0.621     -3.585        0.621         0.622     -3.030        0.622
# 0         0.621     -3.585        0.621         0.622     -3.030        0.622
# 2         0.128     -3.783        0.128         0.128     -2.073        0.128
# 2         0.128     -3.783        0.128         0.128     -2.073        0.128
# 3         0.206     -3.819        0.206         0.206     -2.359        0.206
# 3         0.206     -3.819        0.206         0.206     -2.359        0.206
# 4         0.430     -3.981        0.430         0.430     -3.175        0.430
# 4         0.430     -3.981        0.430         0.430     -3.175        0.430
# 0         0.191     -4.040        0.191         0.191     -3.441        0.191
# 0         0.191     -4.040        0.191         0.191     -3.441        0.191
# 0         0.246     -4.880        0.246         0.246     -3.625        0.246
# 0         0.246     -4.880        0.246         0.246     -3.625        0.246
# 0         0.362     -5.260        0.362         0.362     -4.580        0.362
# 0         0.362     -5.260        0.362         0.362     -4.580        0.362
# 0         0.429     -6.616        0.429         0.450     -6.309        0.450
# 0         0.429     -6.616        0.429         0.450     -6.309        0.450
# 0         0.248     -7.187        0.248         0.275     -5.168        0.275
# 0         0.248     -7.187        0.248         0.275     -5.168        0.275
# 0         0.405    -11.506        0.405         0.405    -10.723        0.405
# 0         0.405    -11.506        0.405         0.405    -10.723        0.405
# 0         0.647    -12.109        0.647         0.647     -9.775        0.647
# 0         0.647    -12.109        0.647         0.647     -9.775        0.647
# 0         0.640    -12.476        0.640         0.642    -10.013        0.642
# 0         0.640    -12.476        0.640         0.642    -10.013        0.642
# 0         0.303    -13.454        0.303         0.307    -12.430        0.307
# 0         0.303    -13.454        0.303         0.307    -12.430        0.307
# 0         0.462    -14.687        0.462         0.462    -13.113        0.462
# 0         0.462    -14.687        0.462         0.462    -13.113        0.462
# 0         0.453    -14.742        0.453         0.457    -12.962        0.457
# 0         0.453    -14.742        0.453         0.457    -12.962        0.457
# 0         0.435    -16.441        0.435         0.447    -13.541        0.447
# 0         0.435    -16.441        0.435         0.447    -13.541        0.447
# 0         0.615    -19.507        0.615         0.624    -16.094        0.624
# 0         0.615    -19.507        0.615         0.624    -16.094        0.624
# 0         0.630    -19.511        0.630         0.630    -16.139        0.630
# 0         0.630    -19.511        0.630         0.630    -16.139        0.630
# 0         0.477    -20.948        0.477         0.477    -18.144        0.477
# 0         0.477    -20.948        0.477         0.477    -18.144        0.477
# 0         0.318    -31.489        0.318         0.320    -27.544        0.320
# 0         0.318    -31.489        0.318         0.320    -27.544        0.320
# 0         0.326    -32.284        0.326         0.326    -28.058        0.326
# 0         0.326    -32.284        0.326         0.326    -28.058        0.326

# %%
def check_path(path):
    files = path.split('/')
    tmp_path = ''
    
    for file in files:
        tmp_path += f"{file}/"
        if not os.path.exists(tmp_path):
            os.mkdir(tmp_path)
        else:
            print(f'File: **{file}** exists')

# %% [markdown]
# ---
# ### Creating tables

# %%
all_metrics.head()
# Out:
#            Satellite  Scaler    Features Property  Model  CC Train All  \
# 0  landsat_simulated  minmax  scE_d1_d2_       pH     LR         0.776
# 1  landsat_simulated  minmax  scE_d1_d2_       pH    SVR         0.764
# 2  landsat_simulated  minmax  scE_d1_d2_       pH  LASSO         0.775
# 3  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR2         0.672
# 4  landsat_simulated  minmax  scE_d1_d2_       pH  PLSR6         0.766
#
#    CC Test All  MSE Train All  MSE CV All  MSE Test All  R2 Train All  \
# 0        0.804          0.536       0.595         0.618         0.602
# 1        0.776          0.562       0.625         0.674         0.582
# 2        0.798          0.537       0.607         0.632         0.601
# 3        0.677          0.739       0.796         0.910         0.451
# 4        0.786          0.557       0.602         0.656         0.586
#
#    R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0      0.533        0.631         0.602      0.559        0.635
# 1      0.507        0.598         0.582      0.532        0.599
# 2      0.524        0.623         0.601      0.552        0.627
# 3      0.368        0.457         0.451      0.396        0.457
# 4      0.526        0.609         0.586      0.552        0.611

# %%
for property_ in list(all_metrics['Property'].unique()):
    for scaler in list(all_metrics['Scaler'].unique()):
        for features in list(all_metrics['Features'].unique()):
            temp_df = all_metrics[
                (all_metrics['Property'] == property_) &
                (all_metrics['Scaler'] == scaler) &
                (all_metrics['Features'] == features)
            ].sort_values(
                by=[
                    'R2 CV All', 'R2 Test All'
                ],
                ascending=False
            ).copy().reset_index(drop=True)
            test_data_path_ = str(
                "../reports/metrics/" +
                f"{scaler}/{features}"
            )
            check_path(test_data_path_)
                
            temp_df.to_csv(
                f"{test_data_path_}/result_metrics_{property_}.csv",
                sep=';',
                decimal='.',
                index=False
            )
            display(temp_df.head(10))
# Out:
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_** exists
#                      Satellite  Scaler    Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_       pH  LASSO
# 1              desis_simulated  minmax  scE_d1_d2_       pH    SVR
# 2          sentinel2_simulated  minmax  scE_d1_d2_       pH  PLSR6
# 3  sentinel2_simulated_indices  minmax  scE_d1_d2_       pH  PLSR6
# 4              desis_simulated  minmax  scE_d1_d2_       pH     RF
# 5          sentinel2_simulated  minmax  scE_d1_d2_       pH    SVR
# 6  sentinel2_simulated_indices  minmax  scE_d1_d2_       pH    SVR
# 7          sentinel2_simulated  minmax  scE_d1_d2_       pH     RF
# 8              desis_simulated  minmax  scE_d1_d2_       pH  PLSR6
# 9  sentinel2_simulated_indices  minmax  scE_d1_d2_       pH     RF
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.879        0.898          0.307       0.397         0.355
# 1         0.869        0.891          0.330       0.420         0.371
# 2         0.832        0.858          0.413       0.459         0.474
# 3         0.832        0.858          0.413       0.459         0.474
# 4         0.912        0.892          0.233       0.495         0.372
# 5         0.832        0.860          0.415       0.476         0.462
# 6         0.832        0.860          0.415       0.476         0.462
# 7         0.897        0.856          0.271       0.493         0.469
# 8         0.843        0.870          0.390       0.492         0.436
# 9         0.896        0.850          0.272       0.527         0.482
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.772      0.681        0.788         0.772      0.686        0.790
# 1         0.755      0.660        0.778         0.755      0.677        0.781
# 2         0.693      0.626        0.717         0.693      0.642        0.719
# 3         0.693      0.626        0.717         0.693      0.642        0.719
# 4         0.827      0.622        0.778         0.827      0.661        0.779
# 5         0.692      0.618        0.724         0.692      0.641        0.726
# 6         0.692      0.618        0.724         0.692      0.641        0.726
# 7         0.799      0.616        0.720         0.799      0.648        0.721
# 8         0.710      0.599        0.740         0.710      0.616        0.741
# 9         0.798      0.594        0.712         0.798      0.637        0.713
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_** exists
#                      Satellite  Scaler        Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_fft_       pH  LASSO
# 1              desis_simulated  minmax  scE_d1_d2_fft_       pH    SVR
# 2              desis_simulated  minmax  scE_d1_d2_fft_       pH     RF
# 3          sentinel2_simulated  minmax  scE_d1_d2_fft_       pH    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_       pH    SVR
# 5          sentinel2_simulated  minmax  scE_d1_d2_fft_       pH     LR
# 6  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_       pH     LR
# 7          sentinel2_simulated  minmax  scE_d1_d2_fft_       pH     RF
# 8  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_       pH     RF
# 9          sentinel2_simulated  minmax  scE_d1_d2_fft_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.879        0.898          0.307       0.397         0.355
# 1         0.869        0.891          0.330       0.420         0.371
# 2         0.913        0.889          0.233       0.494         0.382
# 3         0.832        0.860          0.415       0.477         0.462
# 4         0.832        0.860          0.415       0.477         0.462
# 5         0.847        0.855          0.381       0.500         0.459
# 6         0.847        0.855          0.381       0.500         0.459
# 7         0.897        0.842          0.269       0.521         0.501
# 8         0.898        0.848          0.268       0.527         0.489
# 9         0.842        0.858          0.391       0.510         0.462
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.772      0.681        0.788         0.772      0.686        0.790
# 1         0.755      0.660        0.778         0.755      0.677        0.781
# 2         0.827      0.623        0.772         0.827      0.659        0.773
# 3         0.692      0.618        0.724         0.692      0.641        0.726
# 4         0.692      0.618        0.724         0.692      0.641        0.726
# 5         0.717      0.601        0.726         0.717      0.639        0.727
# 6         0.717      0.601        0.726         0.717      0.639        0.727
# 7         0.800      0.598        0.701         0.800      0.638        0.702
# 8         0.801      0.594        0.708         0.801      0.637        0.709
# 9         0.709      0.592        0.724         0.709      0.634        0.725
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
#                      Satellite  Scaler       Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_cr_       pH  LASSO
# 1              desis_simulated  minmax  scE_d1_d2_cr_       pH    SVR
# 2              desis_simulated  minmax  scE_d1_d2_cr_       pH     RF
# 3          sentinel2_simulated  minmax  scE_d1_d2_cr_       pH    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_cr_       pH    SVR
# 5              desis_simulated  minmax  scE_d1_d2_cr_       pH  PLSR6
# 6          sentinel2_simulated  minmax  scE_d1_d2_cr_       pH     RF
# 7  sentinel2_simulated_indices  minmax  scE_d1_d2_cr_       pH     RF
# 8          sentinel2_simulated  minmax  scE_d1_d2_cr_       pH  LASSO
# 9  sentinel2_simulated_indices  minmax  scE_d1_d2_cr_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.884        0.901          0.294       0.380         0.334
# 1         0.873        0.884          0.321       0.431         0.379
# 2         0.910        0.882          0.237       0.478         0.400
# 3         0.834        0.852          0.410       0.478         0.472
# 4         0.834        0.852          0.410       0.478         0.472
# 5         0.831        0.863          0.416       0.485         0.450
# 6         0.898        0.849          0.267       0.529         0.487
# 7         0.897        0.839          0.270       0.529         0.513
# 8         0.848        0.861          0.378       0.518         0.448
# 9         0.848        0.861          0.378       0.518         0.448
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.782      0.696        0.801         0.782      0.702        0.801
# 1         0.762      0.655        0.774         0.762      0.678        0.775
# 2         0.824      0.635        0.761         0.824      0.667        0.762
# 3         0.695      0.614        0.718         0.696      0.635        0.719
# 4         0.695      0.614        0.718         0.696      0.635        0.719
# 5         0.691      0.600        0.731         0.691      0.604        0.731
# 6         0.802      0.592        0.709         0.802      0.633        0.710
# 7         0.799      0.591        0.694         0.799      0.633        0.695
# 8         0.719      0.583        0.732         0.719      0.624        0.733
# 9         0.719      0.583        0.732         0.719      0.624        0.733
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_cr_** exists
#                      Satellite  Scaler           Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_fft_cr_       pH  LASSO
# 1              desis_simulated  minmax  scE_d1_d2_fft_cr_       pH    SVR
# 2              desis_simulated  minmax  scE_d1_d2_fft_cr_       pH     RF
# 3          sentinel2_simulated  minmax  scE_d1_d2_fft_cr_       pH    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_cr_       pH    SVR
# 5              desis_simulated  minmax  scE_d1_d2_fft_cr_       pH  PLSR6
# 6  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_cr_       pH     RF
# 7          sentinel2_simulated  minmax  scE_d1_d2_fft_cr_       pH     RF
# 8          sentinel2_simulated  minmax  scE_d1_d2_fft_cr_       pH  LASSO
# 9  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_cr_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.884        0.901          0.294       0.380         0.334
# 1         0.873        0.884          0.321       0.431         0.379
# 2         0.911        0.883          0.236       0.492         0.394
# 3         0.834        0.852          0.410       0.478         0.472
# 4         0.834        0.852          0.410       0.478         0.472
# 5         0.831        0.863          0.416       0.485         0.450
# 6         0.898        0.845          0.267       0.528         0.496
# 7         0.899        0.840          0.264       0.535         0.509
# 8         0.848        0.861          0.378       0.518         0.448
# 9         0.848        0.861          0.378       0.518         0.448
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.782      0.696        0.801         0.782      0.702        0.801
# 1         0.762      0.655        0.774         0.762      0.678        0.775
# 2         0.825      0.625        0.765         0.825      0.660        0.765
# 3         0.695      0.614        0.718         0.696      0.635        0.719
# 4         0.695      0.614        0.718         0.696      0.635        0.719
# 5         0.691      0.600        0.731         0.691      0.604        0.731
# 6         0.801      0.591        0.704         0.801      0.630        0.705
# 7         0.804      0.586        0.696         0.804      0.628        0.697
# 8         0.719      0.583        0.732         0.719      0.624        0.733
# 9         0.719      0.583        0.732         0.719      0.624        0.733
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_** exists
#                      Satellite    Scaler    Features Property  Model  \
# 0              desis_simulated  standard  scE_d1_d2_       pH    SVR
# 1              desis_simulated  standard  scE_d1_d2_       pH  LASSO
# 2          sentinel2_simulated  standard  scE_d1_d2_       pH    SVR
# 3  sentinel2_simulated_indices  standard  scE_d1_d2_       pH    SVR
# 4          sentinel2_simulated  standard  scE_d1_d2_       pH  PLSR6
# 5  sentinel2_simulated_indices  standard  scE_d1_d2_       pH  PLSR6
# 6              desis_simulated  standard  scE_d1_d2_       pH     RF
# 7  sentinel2_simulated_indices  standard  scE_d1_d2_       pH     RF
# 8              desis_simulated  standard  scE_d1_d2_       pH  PLSR6
# 9          sentinel2_simulated  standard  scE_d1_d2_       pH     LR
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.880        0.897          0.305       0.395         0.342
# 1         0.879        0.897          0.306       0.400         0.356
# 2         0.841        0.859          0.395       0.443         0.452
# 3         0.841        0.859          0.395       0.443         0.452
# 4         0.832        0.858          0.413       0.459         0.474
# 5         0.832        0.858          0.413       0.459         0.474
# 6         0.910        0.889          0.238       0.498         0.384
# 7         0.898        0.858          0.268       0.513         0.468
# 8         0.843        0.870          0.390       0.492         0.436
# 9         0.842        0.856          0.391       0.511         0.465
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.773      0.684        0.796         0.773      0.696        0.800
# 1         0.773      0.679        0.787         0.773      0.684        0.789
# 2         0.707      0.638        0.730         0.707      0.650        0.732
# 3         0.707      0.638        0.730         0.707      0.650        0.732
# 4         0.693      0.626        0.717         0.693      0.642        0.719
# 5         0.693      0.626        0.717         0.693      0.642        0.719
# 6         0.823      0.621        0.771         0.823      0.658        0.771
# 7         0.801      0.603        0.721         0.801      0.643        0.722
# 8         0.710      0.599        0.740         0.710      0.616        0.741
# 9         0.710      0.591        0.722         0.710      0.633        0.723
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_** exists
#                      Satellite    Scaler        Features Property  Model  \
# 0              desis_simulated  standard  scE_d1_d2_fft_       pH    SVR
# 1              desis_simulated  standard  scE_d1_d2_fft_       pH  LASSO
# 2              desis_simulated  standard  scE_d1_d2_fft_       pH     RF
# 3          sentinel2_simulated  standard  scE_d1_d2_fft_       pH    SVR
# 4  sentinel2_simulated_indices  standard  scE_d1_d2_fft_       pH    SVR
# 5          sentinel2_simulated  standard  scE_d1_d2_fft_       pH     LR
# 6  sentinel2_simulated_indices  standard  scE_d1_d2_fft_       pH     LR
# 7          sentinel2_simulated  standard  scE_d1_d2_fft_       pH     RF
# 8  sentinel2_simulated_indices  standard  scE_d1_d2_fft_       pH     RF
# 9          sentinel2_simulated  standard  scE_d1_d2_fft_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.880        0.896          0.305       0.395         0.342
# 1         0.879        0.897          0.306       0.400         0.356
# 2         0.913        0.887          0.233       0.468         0.388
# 3         0.841        0.859          0.395       0.443         0.452
# 4         0.841        0.859          0.395       0.443         0.452
# 5         0.847        0.855          0.381       0.499         0.459
# 6         0.847        0.855          0.381       0.499         0.459
# 7         0.897        0.847          0.271       0.519         0.491
# 8         0.898        0.848          0.268       0.527         0.490
# 9         0.842        0.858          0.391       0.516         0.462
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.773      0.684        0.796         0.773      0.696        0.800
# 1         0.773      0.679        0.787         0.773      0.684        0.789
# 2         0.827      0.643        0.769         0.827      0.671        0.770
# 3         0.707      0.638        0.730         0.707      0.650        0.732
# 4         0.707      0.638        0.730         0.707      0.650        0.732
# 5         0.717      0.602        0.726         0.717      0.639        0.727
# 6         0.717      0.602        0.726         0.717      0.639        0.727
# 7         0.799      0.599        0.707         0.799      0.638        0.708
# 8         0.801      0.594        0.708         0.801      0.639        0.709
# 9         0.709      0.588        0.724         0.709      0.632        0.725
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
#                      Satellite    Scaler       Features Property  Model  \
# 0              desis_simulated  standard  scE_d1_d2_cr_       pH    SVR
# 1              desis_simulated  standard  scE_d1_d2_cr_       pH  LASSO
# 2              desis_simulated  standard  scE_d1_d2_cr_       pH     RF
# 3              desis_simulated  standard  scE_d1_d2_cr_       pH  PLSR6
# 4          sentinel2_simulated  standard  scE_d1_d2_cr_       pH    SVR
# 5  sentinel2_simulated_indices  standard  scE_d1_d2_cr_       pH    SVR
# 6  sentinel2_simulated_indices  standard  scE_d1_d2_cr_       pH     RF
# 7          sentinel2_simulated  standard  scE_d1_d2_cr_       pH     RF
# 8          sentinel2_simulated  standard  scE_d1_d2_cr_       pH  LASSO
# 9  sentinel2_simulated_indices  standard  scE_d1_d2_cr_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.887        0.899          0.288       0.378         0.328
# 1         0.884        0.898          0.295       0.379         0.340
# 2         0.911        0.891          0.237       0.471         0.374
# 3         0.831        0.863          0.416       0.485         0.450
# 4         0.847        0.785          0.381       0.496         0.662
# 5         0.847        0.785          0.381       0.496         0.662
# 6         0.898        0.847          0.268       0.540         0.493
# 7         0.899        0.850          0.266       0.543         0.482
# 8         0.848        0.840          0.378       0.531         0.495
# 9         0.848        0.840          0.378       0.531         0.495
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.786      0.703        0.804         0.787      0.716        0.806
# 1         0.781      0.696        0.797         0.781      0.702        0.798
# 2         0.824      0.639        0.777         0.824      0.663        0.777
# 3         0.691      0.600        0.731         0.691      0.604        0.731
# 4         0.717      0.598        0.605         0.717      0.607        0.605
# 5         0.717      0.598        0.605         0.717      0.607        0.605
# 6         0.801      0.583        0.706         0.801      0.630        0.707
# 7         0.803      0.581        0.712         0.803      0.629        0.713
# 8         0.719      0.574        0.705         0.719      0.618        0.705
# 9         0.719      0.574        0.705         0.719      0.618        0.705
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_cr_** exists
#                      Satellite    Scaler           Features Property  Model  \
# 0              desis_simulated  standard  scE_d1_d2_fft_cr_       pH    SVR
# 1              desis_simulated  standard  scE_d1_d2_fft_cr_       pH  LASSO
# 2              desis_simulated  standard  scE_d1_d2_fft_cr_       pH     RF
# 3              desis_simulated  standard  scE_d1_d2_fft_cr_       pH  PLSR6
# 4          sentinel2_simulated  standard  scE_d1_d2_fft_cr_       pH    SVR
# 5  sentinel2_simulated_indices  standard  scE_d1_d2_fft_cr_       pH    SVR
# 6  sentinel2_simulated_indices  standard  scE_d1_d2_fft_cr_       pH     RF
# 7          sentinel2_simulated  standard  scE_d1_d2_fft_cr_       pH     RF
# 8          sentinel2_simulated  standard  scE_d1_d2_fft_cr_       pH  LASSO
# 9  sentinel2_simulated_indices  standard  scE_d1_d2_fft_cr_       pH  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.887        0.899          0.288       0.378         0.328
# 1         0.884        0.898          0.295       0.379         0.340
# 2         0.912        0.893          0.234       0.488         0.370
# 3         0.831        0.863          0.416       0.485         0.450
# 4         0.847        0.785          0.381       0.496         0.662
# 5         0.847        0.785          0.381       0.496         0.662
# 6         0.900        0.848          0.263       0.536         0.487
# 7         0.899        0.837          0.266       0.554         0.515
# 8         0.848        0.840          0.378       0.531         0.495
# 9         0.848        0.840          0.378       0.531         0.495
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.786      0.703        0.804         0.787      0.716        0.806
# 1         0.781      0.696        0.797         0.781      0.702        0.798
# 2         0.826      0.628        0.779         0.826      0.657        0.779
# 3         0.691      0.600        0.731         0.691      0.604        0.731
# 4         0.717      0.598        0.605         0.717      0.607        0.605
# 5         0.717      0.598        0.605         0.717      0.607        0.605
# 6         0.804      0.588        0.709         0.804      0.631        0.710
# 7         0.802      0.575        0.692         0.802      0.626        0.693
# 8         0.719      0.574        0.705         0.719      0.618        0.705
# 9         0.719      0.574        0.705         0.719      0.618        0.705
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_** exists
#                      Satellite  Scaler    Features Property  Model  \
# 0            landsat_simulated  minmax  scE_d1_d2_       OM     LR
# 1    landsat_simulated_indices  minmax  scE_d1_d2_       OM     LR
# 2            landsat_simulated  minmax  scE_d1_d2_       OM  LASSO
# 3    landsat_simulated_indices  minmax  scE_d1_d2_       OM  LASSO
# 4              desis_simulated  minmax  scE_d1_d2_       OM     RF
# 5              desis_simulated  minmax  scE_d1_d2_       OM    SVR
# 6              desis_simulated  minmax  scE_d1_d2_       OM  PLSR2
# 7          sentinel2_simulated  minmax  scE_d1_d2_       OM    SVR
# 8  sentinel2_simulated_indices  minmax  scE_d1_d2_       OM    SVR
# 9            landsat_simulated  minmax  scE_d1_d2_       OM  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.615        0.463          5.487       5.958         5.203
# 1         0.615        0.463          5.487       5.958         5.203
# 2         0.610        0.449          5.540       5.998         5.304
# 3         0.610        0.449          5.540       5.998         5.304
# 4         0.799        0.454          3.443       6.007         5.055
# 5         0.644        0.506          5.266       6.223         4.744
# 6         0.611        0.429          5.529       6.147         5.331
# 7         0.590        0.456          5.876       6.534         5.024
# 8         0.590        0.456          5.876       6.534         5.024
# 9         0.569        0.421          5.967       6.424         5.310
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.378      0.298        0.147         0.378      0.331        0.166
# 1         0.378      0.298        0.147         0.378      0.331        0.166
# 2         0.372      0.291        0.130         0.372      0.329        0.147
# 3         0.372      0.291        0.130         0.372      0.329        0.147
# 4         0.609      0.290        0.171         0.609      0.332        0.178
# 5         0.403      0.286        0.222         0.415      0.312        0.232
# 6         0.373      0.281        0.126         0.373      0.318        0.127
# 7         0.334      0.244        0.176         0.347      0.276        0.187
# 8         0.334      0.244        0.176         0.347      0.276        0.187
# 9         0.323      0.243        0.129         0.323      0.274        0.139
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_** exists
#                    Satellite  Scaler        Features Property  Model  \
# 0          landsat_simulated  minmax  scE_d1_d2_fft_       OM  LASSO
# 1  landsat_simulated_indices  minmax  scE_d1_d2_fft_       OM  LASSO
# 2            desis_simulated  minmax  scE_d1_d2_fft_       OM    SVR
# 3          landsat_simulated  minmax  scE_d1_d2_fft_       OM     LR
# 4  landsat_simulated_indices  minmax  scE_d1_d2_fft_       OM     LR
# 5            desis_simulated  minmax  scE_d1_d2_fft_       OM     RF
# 6          landsat_simulated  minmax  scE_d1_d2_fft_       OM  PLSR6
# 7  landsat_simulated_indices  minmax  scE_d1_d2_fft_       OM  PLSR6
# 8            desis_simulated  minmax  scE_d1_d2_fft_       OM  PLSR2
# 9        sentinel2_simulated  minmax  scE_d1_d2_fft_       OM    SVR
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.610        0.449          5.541       6.001         5.299
# 1         0.610        0.449          5.541       6.001         5.299
# 2         0.644        0.506          5.266       6.223         4.744
# 3         0.620        0.476          5.428       6.100         5.091
# 4         0.620        0.476          5.428       6.100         5.091
# 5         0.802        0.436          3.406       6.097         5.294
# 6         0.579        0.447          5.860       6.200         5.167
# 7         0.579        0.447          5.860       6.200         5.167
# 8         0.571        0.441          5.944       6.390         5.295
# 9         0.590        0.456          5.875       6.533         5.024
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.372      0.291        0.131         0.372      0.328        0.147
# 1         0.372      0.291        0.131         0.372      0.328        0.147
# 2         0.403      0.286        0.222         0.415      0.312        0.232
# 3         0.384      0.280        0.165         0.385      0.310        0.184
# 4         0.384      0.280        0.165         0.385      0.310        0.184
# 5         0.614      0.276        0.132         0.614      0.321        0.140
# 6         0.335      0.269        0.153         0.335      0.302        0.164
# 7         0.335      0.269        0.153         0.335      0.302        0.164
# 8         0.326      0.248        0.132         0.326      0.287        0.135
# 9         0.334      0.244        0.176         0.347      0.276        0.188
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_cr_** exists
#                    Satellite  Scaler       Features Property  Model  \
# 0          landsat_simulated  minmax  scE_d1_d2_cr_       OM  LASSO
# 1  landsat_simulated_indices  minmax  scE_d1_d2_cr_       OM  LASSO
# 2            desis_simulated  minmax  scE_d1_d2_cr_       OM     RF
# 3          landsat_simulated  minmax  scE_d1_d2_cr_       OM     LR
# 4  landsat_simulated_indices  minmax  scE_d1_d2_cr_       OM     LR
# 5            desis_simulated  minmax  scE_d1_d2_cr_       OM    SVR
# 6          landsat_simulated  minmax  scE_d1_d2_cr_       OM  PLSR6
# 7  landsat_simulated_indices  minmax  scE_d1_d2_cr_       OM  PLSR6
# 8            desis_simulated  minmax  scE_d1_d2_cr_       OM  PLSR2
# 9        sentinel2_simulated  minmax  scE_d1_d2_cr_       OM    SVR
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.625        0.488          5.378       5.932         4.930
# 1         0.625        0.488          5.378       5.932         4.930
# 2         0.805        0.444          3.389       6.032         5.180
# 3         0.631        0.497          5.303       6.098         4.882
# 4         0.631        0.497          5.303       6.098         4.882
# 5         0.661        0.455          5.055       6.433         5.674
# 6         0.585        0.458          5.803       6.265         4.982
# 7         0.585        0.458          5.803       6.265         4.982
# 8         0.560        0.430          6.048       6.252         5.419
# 9         0.595        0.460          5.819       6.583         5.022
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.390      0.301        0.191         0.390      0.336        0.204
# 1         0.390      0.301        0.191         0.390      0.336        0.204
# 2         0.616      0.285        0.151         0.616      0.329        0.160
# 3         0.399      0.280        0.199         0.399      0.314        0.214
# 4         0.399      0.280        0.199         0.399      0.314        0.214
# 5         0.427      0.265        0.070         0.437      0.292        0.072
# 6         0.342      0.264        0.183         0.342      0.298        0.189
# 7         0.342      0.264        0.183         0.342      0.298        0.189
# 8         0.314      0.259        0.111         0.314      0.299        0.115
# 9         0.340      0.239        0.176         0.354      0.269        0.187
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_cr_** exists
#                    Satellite  Scaler           Features Property  Model  \
# 0          landsat_simulated  minmax  scE_d1_d2_fft_cr_       OM  LASSO
# 1  landsat_simulated_indices  minmax  scE_d1_d2_fft_cr_       OM  LASSO
# 2            desis_simulated  minmax  scE_d1_d2_fft_cr_       OM     RF
# 3          landsat_simulated  minmax  scE_d1_d2_fft_cr_       OM     LR
# 4  landsat_simulated_indices  minmax  scE_d1_d2_fft_cr_       OM     LR
# 5            desis_simulated  minmax  scE_d1_d2_fft_cr_       OM    SVR
# 6          landsat_simulated  minmax  scE_d1_d2_fft_cr_       OM  PLSR6
# 7  landsat_simulated_indices  minmax  scE_d1_d2_fft_cr_       OM  PLSR6
# 8            desis_simulated  minmax  scE_d1_d2_fft_cr_       OM  PLSR2
# 9        sentinel2_simulated  minmax  scE_d1_d2_fft_cr_       OM    SVR
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.625        0.488          5.378       5.932         4.930
# 1         0.625        0.488          5.378       5.932         4.930
# 2         0.808        0.442          3.346       5.971         5.169
# 3         0.631        0.497          5.303       6.098         4.882
# 4         0.631        0.497          5.303       6.098         4.882
# 5         0.661        0.455          5.055       6.433         5.674
# 6         0.585        0.458          5.803       6.265         4.982
# 7         0.585        0.458          5.803       6.265         4.982
# 8         0.560        0.430          6.048       6.252         5.419
# 9         0.595        0.460          5.819       6.583         5.022
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.390      0.301        0.191         0.390      0.336        0.204
# 1         0.390      0.301        0.191         0.390      0.336        0.204
# 2         0.620      0.294        0.152         0.620      0.337        0.158
# 3         0.399      0.280        0.199         0.399      0.314        0.214
# 4         0.399      0.280        0.199         0.399      0.314        0.214
# 5         0.427      0.265        0.070         0.437      0.292        0.072
# 6         0.342      0.264        0.183         0.342      0.298        0.189
# 7         0.342      0.264        0.183         0.342      0.298        0.189
# 8         0.314      0.259        0.111         0.314      0.299        0.115
# 9         0.340      0.239        0.176         0.354      0.269        0.187
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_** exists
#                    Satellite    Scaler    Features Property  Model  \
# 0          landsat_simulated  standard  scE_d1_d2_       OM     LR
# 1  landsat_simulated_indices  standard  scE_d1_d2_       OM     LR
# 2          landsat_simulated  standard  scE_d1_d2_       OM  LASSO
# 3  landsat_simulated_indices  standard  scE_d1_d2_       OM  LASSO
# 4            desis_simulated  standard  scE_d1_d2_       OM     RF
# 5          landsat_simulated  standard  scE_d1_d2_       OM    SVR
# 6  landsat_simulated_indices  standard  scE_d1_d2_       OM    SVR
# 7            desis_simulated  standard  scE_d1_d2_       OM  PLSR2
# 8          landsat_simulated  standard  scE_d1_d2_       OM  PLSR6
# 9  landsat_simulated_indices  standard  scE_d1_d2_       OM  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.615        0.463          5.486       5.964         5.184
# 1         0.615        0.463          5.486       5.964         5.184
# 2         0.610        0.449          5.539       5.997         5.306
# 3         0.610        0.449          5.539       5.997         5.306
# 4         0.798        0.439          3.470       6.017         5.200
# 5         0.606        0.457          5.749       6.155         4.994
# 6         0.606        0.457          5.749       6.155         4.994
# 7         0.611        0.429          5.529       6.147         5.331
# 8         0.569        0.421          5.967       6.424         5.310
# 9         0.569        0.421          5.967       6.424         5.310
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.378      0.297        0.150         0.378      0.331        0.165
# 1         0.378      0.297        0.150         0.378      0.331        0.165
# 2         0.372      0.291        0.130         0.372      0.329        0.147
# 3         0.372      0.291        0.130         0.372      0.329        0.147
# 4         0.606      0.287        0.147         0.606      0.330        0.157
# 5         0.348      0.281        0.181         0.364      0.326        0.182
# 6         0.348      0.281        0.181         0.364      0.326        0.182
# 7         0.373      0.281        0.126         0.373      0.318        0.127
# 8         0.323      0.243        0.129         0.323      0.274        0.139
# 9         0.323      0.243        0.129         0.323      0.274        0.139
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_** exists
#                    Satellite    Scaler        Features Property  Model  \
# 0          landsat_simulated  standard  scE_d1_d2_fft_       OM  LASSO
# 1  landsat_simulated_indices  standard  scE_d1_d2_fft_       OM  LASSO
# 2          landsat_simulated  standard  scE_d1_d2_fft_       OM    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_fft_       OM    SVR
# 4          landsat_simulated  standard  scE_d1_d2_fft_       OM     LR
# 5  landsat_simulated_indices  standard  scE_d1_d2_fft_       OM     LR
# 6            desis_simulated  standard  scE_d1_d2_fft_       OM     RF
# 7          landsat_simulated  standard  scE_d1_d2_fft_       OM  PLSR6
# 8  landsat_simulated_indices  standard  scE_d1_d2_fft_       OM  PLSR6
# 9            desis_simulated  standard  scE_d1_d2_fft_       OM  PLSR2
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.610        0.449          5.539       5.997         5.306
# 1         0.610        0.449          5.539       5.997         5.306
# 2         0.606        0.457          5.749       6.156         4.994
# 3         0.606        0.457          5.749       6.156         4.994
# 4         0.620        0.476          5.428       6.101         5.063
# 5         0.620        0.476          5.428       6.101         5.063
# 6         0.796        0.424          3.477       6.103         5.376
# 7         0.579        0.447          5.860       6.200         5.167
# 8         0.579        0.447          5.860       6.200         5.167
# 9         0.571        0.441          5.944       6.390         5.295
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.372      0.291        0.130         0.372      0.329        0.147
# 1         0.372      0.291        0.130         0.372      0.329        0.147
# 2         0.348      0.281        0.181         0.364      0.326        0.182
# 3         0.348      0.281        0.181         0.364      0.326        0.182
# 4         0.384      0.280        0.170         0.384      0.310        0.184
# 5         0.384      0.280        0.170         0.384      0.310        0.184
# 6         0.606      0.276        0.118         0.606      0.320        0.128
# 7         0.335      0.269        0.153         0.335      0.302        0.164
# 8         0.335      0.269        0.153         0.335      0.302        0.164
# 9         0.326      0.248        0.132         0.326      0.287        0.135
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_cr_** exists
#                    Satellite    Scaler       Features Property  Model  \
# 0          landsat_simulated  standard  scE_d1_d2_cr_       OM  LASSO
# 1  landsat_simulated_indices  standard  scE_d1_d2_cr_       OM  LASSO
# 2          landsat_simulated  standard  scE_d1_d2_cr_       OM    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_cr_       OM    SVR
# 4            desis_simulated  standard  scE_d1_d2_cr_       OM     RF
# 5          landsat_simulated  standard  scE_d1_d2_cr_       OM     LR
# 6  landsat_simulated_indices  standard  scE_d1_d2_cr_       OM     LR
# 7          landsat_simulated  standard  scE_d1_d2_cr_       OM  PLSR6
# 8  landsat_simulated_indices  standard  scE_d1_d2_cr_       OM  PLSR6
# 9            desis_simulated  standard  scE_d1_d2_cr_       OM  PLSR2
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.625        0.489          5.368       5.940         4.923
# 1         0.625        0.489          5.368       5.940         4.923
# 2         0.619        0.489          5.567       6.110         4.850
# 3         0.619        0.489          5.567       6.110         4.850
# 4         0.805        0.421          3.348       6.007         5.346
# 5         0.631        0.497          5.303       6.091         4.871
# 6         0.631        0.497          5.303       6.091         4.871
# 7         0.585        0.458          5.803       6.265         4.982
# 8         0.585        0.458          5.803       6.265         4.982
# 9         0.560        0.430          6.048       6.252         5.419
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.391      0.300        0.193         0.391      0.335        0.205
# 1         0.391      0.300        0.193         0.391      0.335        0.205
# 2         0.369      0.288        0.205         0.383      0.331        0.206
# 3         0.369      0.288        0.205         0.383      0.331        0.206
# 4         0.620      0.288        0.123         0.620      0.329        0.132
# 5         0.398      0.282        0.201         0.398      0.313        0.214
# 6         0.398      0.282        0.201         0.398      0.313        0.214
# 7         0.342      0.264        0.183         0.342      0.298        0.189
# 8         0.342      0.264        0.183         0.342      0.298        0.189
# 9         0.314      0.259        0.111         0.314      0.299        0.115
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_cr_** exists
#                    Satellite    Scaler           Features Property  Model  \
# 0          landsat_simulated  standard  scE_d1_d2_fft_cr_       OM  LASSO
# 1  landsat_simulated_indices  standard  scE_d1_d2_fft_cr_       OM  LASSO
# 2          landsat_simulated  standard  scE_d1_d2_fft_cr_       OM    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_fft_cr_       OM    SVR
# 4            desis_simulated  standard  scE_d1_d2_fft_cr_       OM     RF
# 5          landsat_simulated  standard  scE_d1_d2_fft_cr_       OM     LR
# 6  landsat_simulated_indices  standard  scE_d1_d2_fft_cr_       OM     LR
# 7          landsat_simulated  standard  scE_d1_d2_fft_cr_       OM  PLSR6
# 8  landsat_simulated_indices  standard  scE_d1_d2_fft_cr_       OM  PLSR6
# 9            desis_simulated  standard  scE_d1_d2_fft_cr_       OM  PLSR2
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.625        0.489          5.368       5.940         4.923
# 1         0.625        0.489          5.368       5.940         4.923
# 2         0.619        0.489          5.567       6.110         4.850
# 3         0.619        0.489          5.567       6.110         4.850
# 4         0.799        0.459          3.438       6.045         5.021
# 5         0.631        0.497          5.303       6.091         4.871
# 6         0.631        0.497          5.303       6.091         4.871
# 7         0.585        0.458          5.803       6.265         4.982
# 8         0.585        0.458          5.803       6.265         4.982
# 9         0.560        0.430          6.048       6.252         5.419
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.391      0.300        0.193         0.391      0.335        0.205
# 1         0.391      0.300        0.193         0.391      0.335        0.205
# 2         0.369      0.288        0.205         0.383      0.331        0.206
# 3         0.369      0.288        0.205         0.383      0.331        0.206
# 4         0.610      0.285        0.177         0.610      0.328        0.184
# 5         0.398      0.282        0.201         0.398      0.313        0.214
# 6         0.398      0.282        0.201         0.398      0.313        0.214
# 7         0.342      0.264        0.183         0.342      0.298        0.189
# 8         0.342      0.264        0.183         0.342      0.298        0.189
# 9         0.314      0.259        0.111         0.314      0.299        0.115
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_** exists
#                      Satellite  Scaler    Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_       Ca    SVR
# 1              desis_simulated  minmax  scE_d1_d2_       Ca     RF
# 2          sentinel2_simulated  minmax  scE_d1_d2_       Ca    SVR
# 3  sentinel2_simulated_indices  minmax  scE_d1_d2_       Ca    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_       Ca     RF
# 5          sentinel2_simulated  minmax  scE_d1_d2_       Ca     RF
# 6            landsat_simulated  minmax  scE_d1_d2_       Ca    SVR
# 7    landsat_simulated_indices  minmax  scE_d1_d2_       Ca    SVR
# 8              desis_simulated  minmax  scE_d1_d2_       Ca  LASSO
# 9          sentinel2_simulated  minmax  scE_d1_d2_       Ca  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.681        0.666        103.900     133.082       183.232
# 1         0.842        0.647         54.611     125.189       161.430
# 2         0.647        0.619        127.426     160.987       212.653
# 3         0.647        0.619        127.426     160.987       212.653
# 4         0.830        0.687         58.496     118.855       147.382
# 5         0.827        0.694         59.134     119.016       145.048
# 6         0.593        0.559        135.309     162.342       223.827
# 7         0.593        0.559        135.309     162.342       223.827
# 8         0.750        0.686         78.321     115.687       152.611
# 9         0.677        0.623         96.589     124.692       172.997
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.418      0.197        0.337         0.440      0.287        0.362
# 1         0.694      0.154        0.416         0.694      0.270        0.416
# 2         0.286      0.120        0.230         0.341      0.270        0.278
# 3         0.286      0.120        0.230         0.341      0.270        0.278
# 4         0.672      0.119        0.466         0.672      0.231        0.467
# 5         0.669      0.107        0.475         0.669      0.228        0.475
# 6         0.242      0.055        0.190         0.299      0.188        0.242
# 7         0.242      0.055        0.190         0.299      0.188        0.242
# 8         0.561      0.047        0.447         0.561      0.094        0.450
# 9         0.459      0.013        0.374         0.459      0.123        0.377
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_** exists
#                      Satellite  Scaler        Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_fft_       Ca    SVR
# 1              desis_simulated  minmax  scE_d1_d2_fft_       Ca     RF
# 2  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_       Ca     RF
# 3          sentinel2_simulated  minmax  scE_d1_d2_fft_       Ca    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_fft_       Ca    SVR
# 5          sentinel2_simulated  minmax  scE_d1_d2_fft_       Ca     RF
# 6            landsat_simulated  minmax  scE_d1_d2_fft_       Ca    SVR
# 7    landsat_simulated_indices  minmax  scE_d1_d2_fft_       Ca    SVR
# 8              desis_simulated  minmax  scE_d1_d2_fft_       Ca  LASSO
# 9          sentinel2_simulated  minmax  scE_d1_d2_fft_       Ca  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.681        0.666        103.900     133.081       183.232
# 1         0.847        0.653         53.520     126.557       159.783
# 2         0.830        0.684         58.148     118.882       148.481
# 3         0.647        0.620        127.410     160.943       212.637
# 4         0.647        0.620        127.410     160.943       212.637
# 5         0.828        0.677         58.767     120.789       150.628
# 6         0.593        0.559        135.233     162.355       223.780
# 7         0.593        0.559        135.233     162.355       223.780
# 8         0.750        0.686         78.320     115.687       152.611
# 9         0.675        0.615         97.203     133.327       176.123
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.418      0.197        0.337         0.440      0.287        0.362
# 1         0.700      0.147        0.421         0.700      0.269        0.422
# 2         0.674      0.121        0.462         0.674      0.240        0.463
# 3         0.286      0.121        0.230         0.341      0.270        0.278
# 4         0.286      0.121        0.230         0.341      0.270        0.278
# 5         0.671      0.100        0.455         0.671      0.226        0.455
# 6         0.242      0.055        0.190         0.299      0.188        0.242
# 7         0.242      0.055        0.190         0.299      0.188        0.242
# 8         0.561      0.047        0.447         0.561      0.094        0.450
# 9         0.455      0.024        0.362         0.455      0.147        0.367
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_cr_** exists
#                      Satellite  Scaler       Features Property  Model  \
# 0              desis_simulated  minmax  scE_d1_d2_cr_       Ca    SVR
# 1              desis_simulated  minmax  scE_d1_d2_cr_       Ca     RF
# 2          sentinel2_simulated  minmax  scE_d1_d2_cr_       Ca     RF
# 3          sentinel2_simulated  minmax  scE_d1_d2_cr_       Ca    SVR
# 4  sentinel2_simulated_indices  minmax  scE_d1_d2_cr_       Ca    SVR
# 5  sentinel2_simulated_indices  minmax  scE_d1_d2_cr_       Ca     RF
# 6              desis_simulated  minmax  scE_d1_d2_cr_       Ca  LASSO
# 7            landsat_simulated  minmax  scE_d1_d2_cr_       Ca    SVR
# 8    landsat_simulated_indices  minmax  scE_d1_d2_cr_       Ca    SVR
# 9          sentinel2_simulated  minmax  scE_d1_d2_cr_       Ca     LR
#
# ...
# 7         0.017     -0.545       -0.034         0.052     -0.033       -0.003
# 8         0.022     -0.555       -0.009         0.022     -0.035        0.006
# 9         0.022     -0.555       -0.009         0.022     -0.035        0.006
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_cr_** exists
#                    Satellite  Scaler       Features Property  Model  \
# 0              sentinel2_all  minmax  scE_d1_d2_cr_       Na    SVR
# 1      sentinel2_all_indices  minmax  scE_d1_d2_cr_       Na    SVR
# 2          landsat_simulated  minmax  scE_d1_d2_cr_       Na    SVR
# 3  landsat_simulated_indices  minmax  scE_d1_d2_cr_       Na    SVR
# 4              sentinel2_all  minmax  scE_d1_d2_cr_       Na  LASSO
# 5      sentinel2_all_indices  minmax  scE_d1_d2_cr_       Na  LASSO
# 6              sentinel2_all  minmax  scE_d1_d2_cr_       Na  PLSR2
# 7      sentinel2_all_indices  minmax  scE_d1_d2_cr_       Na  PLSR2
# 8              sentinel2_all  minmax  scE_d1_d2_cr_       Na  PLSR6
# 9      sentinel2_all_indices  minmax  scE_d1_d2_cr_       Na  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.192        0.243          0.047       0.053         0.081
# 1         0.192        0.243          0.047       0.053         0.081
# 2         0.228        0.190          0.048       0.052         0.046
# 3         0.228        0.190          0.048       0.052         0.046
# 4         0.111        0.121          0.047       0.055         0.080
# 5         0.111        0.121          0.047       0.055         0.080
# 6         0.152        0.120          0.046       0.055         0.080
# 7         0.152        0.120          0.046       0.055         0.080
# 8         0.214        0.347          0.045       0.055         0.074
# 9         0.214        0.347          0.045       0.055         0.074
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.004     -0.210       -0.012         0.035      0.029        0.043
# 1         0.004     -0.210       -0.012         0.035      0.029        0.043
# 2         0.012     -0.322        0.005         0.043      0.018        0.031
# 3         0.012     -0.322        0.005         0.043      0.018        0.031
# 4         0.002     -0.551       -0.005         0.002     -0.011        0.002
# 5         0.002     -0.551       -0.005         0.002     -0.011        0.002
# 6         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 7         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 8         0.046     -0.574        0.076         0.046     -0.051        0.090
# 9         0.046     -0.574        0.076         0.046     -0.051        0.090
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **minmax** exists
# File: **scE_d1_d2_fft_cr_** exists
#                    Satellite  Scaler           Features Property  Model  \
# 0              sentinel2_all  minmax  scE_d1_d2_fft_cr_       Na    SVR
# 1      sentinel2_all_indices  minmax  scE_d1_d2_fft_cr_       Na    SVR
# 2          landsat_simulated  minmax  scE_d1_d2_fft_cr_       Na    SVR
# 3  landsat_simulated_indices  minmax  scE_d1_d2_fft_cr_       Na    SVR
# 4              sentinel2_all  minmax  scE_d1_d2_fft_cr_       Na  LASSO
# 5      sentinel2_all_indices  minmax  scE_d1_d2_fft_cr_       Na  LASSO
# 6              sentinel2_all  minmax  scE_d1_d2_fft_cr_       Na  PLSR2
# 7      sentinel2_all_indices  minmax  scE_d1_d2_fft_cr_       Na  PLSR2
# 8              sentinel2_all  minmax  scE_d1_d2_fft_cr_       Na  PLSR6
# 9      sentinel2_all_indices  minmax  scE_d1_d2_fft_cr_       Na  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.192        0.243          0.047       0.053         0.081
# 1         0.192        0.243          0.047       0.053         0.081
# 2         0.228        0.190          0.048       0.052         0.046
# 3         0.228        0.190          0.048       0.052         0.046
# 4         0.111        0.121          0.047       0.055         0.080
# 5         0.111        0.121          0.047       0.055         0.080
# 6         0.152        0.120          0.046       0.055         0.080
# 7         0.152        0.120          0.046       0.055         0.080
# 8         0.214        0.347          0.045       0.055         0.074
# 9         0.214        0.347          0.045       0.055         0.074
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.004     -0.210       -0.012         0.035      0.029        0.043
# 1         0.004     -0.210       -0.012         0.035      0.029        0.043
# 2         0.012     -0.322        0.005         0.043      0.018        0.031
# 3         0.012     -0.322        0.005         0.043      0.018        0.031
# 4         0.002     -0.551       -0.005         0.002     -0.011        0.002
# 5         0.002     -0.551       -0.005         0.002     -0.011        0.002
# 6         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 7         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 8         0.046     -0.574        0.076         0.046     -0.051        0.090
# 9         0.046     -0.574        0.076         0.046     -0.051        0.090
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_** exists
#                    Satellite    Scaler    Features Property  Model  \
# 0              sentinel2_all  standard  scE_d1_d2_       Na    SVR
# 1      sentinel2_all_indices  standard  scE_d1_d2_       Na    SVR
# 2          landsat_simulated  standard  scE_d1_d2_       Na    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_       Na    SVR
# 4              sentinel2_all  standard  scE_d1_d2_       Na     LR
# 5      sentinel2_all_indices  standard  scE_d1_d2_       Na     LR
# 6              sentinel2_all  standard  scE_d1_d2_       Na  PLSR6
# 7      sentinel2_all_indices  standard  scE_d1_d2_       Na  PLSR6
# 8              sentinel2_all  standard  scE_d1_d2_       Na  LASSO
# 9      sentinel2_all_indices  standard  scE_d1_d2_       Na  LASSO
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.177        0.146          0.047       0.053         0.083
# 1         0.177        0.146          0.047       0.053         0.083
# 2         0.240        0.207          0.047       0.052         0.045
# 3         0.240        0.207          0.047       0.052         0.045
# 4         0.196        0.091          0.045       0.055         0.081
# 5         0.196        0.091          0.045       0.055         0.081
# 6         0.186        0.185          0.045       0.055         0.078
# 7         0.186        0.185          0.045       0.055         0.078
# 8           NaN          NaN          0.047       0.055         0.080
# 9           NaN          NaN          0.047       0.055         0.080
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0        -0.003     -0.228       -0.036         0.031      0.009        0.021
# 1        -0.003     -0.228       -0.036         0.031      0.009        0.021
# 2         0.027     -0.326        0.013         0.052      0.010        0.038
# 3         0.027     -0.326        0.013         0.052      0.010        0.038
# 4         0.038     -0.555       -0.010         0.038     -0.028        0.003
# 5         0.038     -0.555       -0.010         0.038     -0.028        0.003
# 6         0.035     -0.556        0.018         0.035     -0.027        0.032
# 7         0.035     -0.556        0.018         0.035     -0.027        0.032
# 8         0.000     -0.563       -0.007         0.000     -0.021        0.000
# 9         0.000     -0.563       -0.007         0.000     -0.021        0.000
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_** exists
#                    Satellite    Scaler        Features Property  Model  \
# 0              sentinel2_all  standard  scE_d1_d2_fft_       Na    SVR
# 1      sentinel2_all_indices  standard  scE_d1_d2_fft_       Na    SVR
# 2          landsat_simulated  standard  scE_d1_d2_fft_       Na    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_fft_       Na    SVR
# 4              sentinel2_all  standard  scE_d1_d2_fft_       Na  PLSR2
# 5      sentinel2_all_indices  standard  scE_d1_d2_fft_       Na  PLSR2
# 6              sentinel2_all  standard  scE_d1_d2_fft_       Na  LASSO
# 7      sentinel2_all_indices  standard  scE_d1_d2_fft_       Na  LASSO
# 8              sentinel2_all  standard  scE_d1_d2_fft_       Na  PLSR6
# 9      sentinel2_all_indices  standard  scE_d1_d2_fft_       Na  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.177        0.145          0.047       0.053         0.083
# 1         0.177        0.145          0.047       0.053         0.083
# 2         0.242        0.208          0.047       0.052         0.045
# 3         0.242        0.208          0.047       0.052         0.045
# 4         0.150        0.093          0.046       0.055         0.081
# 5         0.150        0.093          0.046       0.055         0.081
# 6           NaN          NaN          0.047       0.055         0.080
# 7           NaN          NaN          0.047       0.055         0.080
# 8         0.210        0.299          0.045       0.055         0.075
# 9         0.210        0.299          0.045       0.055         0.075
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0        -0.003     -0.228       -0.037         0.031      0.009        0.021
# 1        -0.003     -0.228       -0.037         0.031      0.009        0.021
# 2         0.028     -0.325        0.014         0.053      0.010        0.039
# 3         0.028     -0.325        0.014         0.053      0.010        0.039
# 4         0.022     -0.555       -0.009         0.022     -0.035        0.006
# 5         0.022     -0.555       -0.009         0.022     -0.035        0.006
# 6         0.000     -0.566       -0.007         0.000     -0.023        0.000
# 7         0.000     -0.566       -0.007         0.000     -0.023        0.000
# 8         0.044     -0.567        0.059         0.044     -0.042        0.073
# 9         0.044     -0.567        0.059         0.044     -0.042        0.073
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_cr_** exists
#                    Satellite    Scaler       Features Property  Model  \
# 0              sentinel2_all  standard  scE_d1_d2_cr_       Na    SVR
# 1      sentinel2_all_indices  standard  scE_d1_d2_cr_       Na    SVR
# 2          landsat_simulated  standard  scE_d1_d2_cr_       Na    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_cr_       Na    SVR
# 4              sentinel2_all  standard  scE_d1_d2_cr_       Na  LASSO
# 5      sentinel2_all_indices  standard  scE_d1_d2_cr_       Na  LASSO
# 6              sentinel2_all  standard  scE_d1_d2_cr_       Na  PLSR2
# 7      sentinel2_all_indices  standard  scE_d1_d2_cr_       Na  PLSR2
# 8              sentinel2_all  standard  scE_d1_d2_cr_       Na  PLSR6
# 9      sentinel2_all_indices  standard  scE_d1_d2_cr_       Na  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.235        0.276          0.046       0.052         0.080
# 1         0.235        0.276          0.046       0.052         0.080
# 2         0.255        0.208          0.046       0.051         0.045
# 3         0.255        0.208          0.046       0.051         0.045
# 4         0.267        0.215          0.043       0.055         0.077
# 5         0.267        0.215          0.043       0.055         0.077
# 6         0.152        0.120          0.046       0.055         0.080
# 7         0.152        0.120          0.046       0.055         0.080
# 8         0.214        0.347          0.045       0.055         0.074
# 9         0.214        0.347          0.045       0.055         0.074
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.021     -0.201        0.002         0.052      0.013        0.055
# 1         0.021     -0.201        0.002         0.052      0.013        0.055
# 2         0.034     -0.332        0.014         0.060      0.022        0.040
# 3         0.034     -0.332        0.014         0.060      0.022        0.040
# 4         0.071     -0.547        0.032         0.071     -0.011        0.045
# 5         0.071     -0.547        0.032         0.071     -0.011        0.045
# 6         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 7         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 8         0.046     -0.574        0.076         0.046     -0.051        0.090
# 9         0.046     -0.574        0.076         0.046     -0.051        0.090
# File: **..** exists
# File: **reports** exists
# File: **metrics** exists
# File: **standard** exists
# File: **scE_d1_d2_fft_cr_** exists
#                    Satellite    Scaler           Features Property  Model  \
# 0              sentinel2_all  standard  scE_d1_d2_fft_cr_       Na    SVR
# 1      sentinel2_all_indices  standard  scE_d1_d2_fft_cr_       Na    SVR
# 2          landsat_simulated  standard  scE_d1_d2_fft_cr_       Na    SVR
# 3  landsat_simulated_indices  standard  scE_d1_d2_fft_cr_       Na    SVR
# 4              sentinel2_all  standard  scE_d1_d2_fft_cr_       Na  LASSO
# 5      sentinel2_all_indices  standard  scE_d1_d2_fft_cr_       Na  LASSO
# 6              sentinel2_all  standard  scE_d1_d2_fft_cr_       Na  PLSR2
# 7      sentinel2_all_indices  standard  scE_d1_d2_fft_cr_       Na  PLSR2
# 8              sentinel2_all  standard  scE_d1_d2_fft_cr_       Na  PLSR6
# 9      sentinel2_all_indices  standard  scE_d1_d2_fft_cr_       Na  PLSR6
#
#    CC Train All  CC Test All  MSE Train All  MSE CV All  MSE Test All  \
# 0         0.235        0.276          0.046       0.052         0.080
# 1         0.235        0.276          0.046       0.052         0.080
# 2         0.255        0.208          0.046       0.051         0.045
# 3         0.255        0.208          0.046       0.051         0.045
# 4         0.267        0.215          0.043       0.055         0.077
# 5         0.267        0.215          0.043       0.055         0.077
# 6         0.152        0.120          0.046       0.055         0.080
# 7         0.152        0.120          0.046       0.055         0.080
# 8         0.214        0.347          0.045       0.055         0.074
# 9         0.214        0.347          0.045       0.055         0.074
#
#    R2 Train All  R2 CV All  R2 Test All  EV Train All  EV CV All  EV Test All
# 0         0.021     -0.201        0.002         0.052      0.013        0.055
# 1         0.021     -0.201        0.002         0.052      0.013        0.055
# 2         0.034     -0.332        0.014         0.060      0.022        0.040
# 3         0.034     -0.332        0.014         0.060      0.022        0.040
# 4         0.071     -0.547        0.032         0.071     -0.011        0.045
# 5         0.071     -0.547        0.032         0.071     -0.011        0.045
# 6         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 7         0.023     -0.557       -0.001         0.023     -0.024        0.014
# 8         0.046     -0.574        0.076         0.046     -0.051        0.090
# 9         0.046     -0.574        0.076         0.046     -0.051        0.090

# %% [markdown]
# ### Individual results

# %%
all_metrics.columns
# Out:
# Index(['Satellite', 'Scaler', 'Features', 'Property', 'Model', 'CC Train All',
#        'CC Test All', 'MSE Train All', 'MSE CV All', 'MSE Test All',
#        'R2 Train All', 'R2 CV All', 'R2 Test All', 'EV Train All', 'EV CV All',
#        'EV Test All'],
#       dtype='object')

# %%
for col in all_metrics.columns[4:]:
    all_metrics[col] = all_metrics[col].apply(lambda x: round(float(x), 3))

# %%
for id_, values in enumerate(all_metrics['Property'].unique()):
    print(f"{id_} {values}")
# Out:
# 0 Ca
# 1 K
# 2 Mg
# 3 Na
# 4 OM
# 5 pH

# %%
# metrics_cols_ = ['CC Test All', 'CC Train All']
metrics_cols_ = ['R2 Test All', 'R2 Train All', 'R2 CV All']
# metrics_cols_ = ['EV Test All', 'EV Train All', 'EV CV All']
# metrics_cols_ = all_metrics.columns.tolist()

# 'Vis-Nir', 
origin_cols = ['landsat', 'sentinel2', 'desis']
properties_cols = ['pH']

df_temp = all_metrics.copy()#.iloc[[i for i in range(0, all_metrics.shape[0], 2)]]
df_temp[
    df_temp['Satellite'].isin(origin_cols) &
    df_temp['Property'].isin(['pH']) &
    df_temp['Scaler'].isin(['minmax'])
]#.sort_values(by=metrics_cols_, ascending=False)
# Out:
#    Satellite Property  Scaler  Model  CC Train All  CC Test All  \
# 0      desis       pH  minmax  LASSO         0.900        0.856
# 0      desis       pH  minmax     LR         0.963        0.182
# 0      desis       pH  minmax  PLSR2         0.682        0.705
# 0      desis       pH  minmax    SVR         0.859        0.830
# 0    landsat       pH  minmax  LASSO         0.807        0.796
# 0    landsat       pH  minmax     LR         0.840        0.681
# 0    landsat       pH  minmax  PLSR2         0.707        0.785
# 0    landsat       pH  minmax    SVR         0.748        0.792
# 0  sentinel2       pH  minmax  LASSO         0.859        0.860
# 0  sentinel2       pH  minmax     LR         0.752       -0.009
# 0  sentinel2       pH  minmax  PLSR2         0.748        0.655
# 0  sentinel2       pH  minmax    SVR         0.824        0.842
#
#    MSE Train All                 MSE CV All              MSE Test All  \
# 0          0.271                      0.370                     0.343
# 0          0.102                    412.140                    61.614
# 0          0.747                      0.627                     0.699
# 0          0.368                      0.459                     0.424
# 0          0.472                      0.547                     0.537
# 0          0.410                      0.781                     0.789
# 0          0.677                      0.593                     0.579
# 0          0.591                      0.746                     0.653
# 0          0.338                      0.442                     0.412
# 0          0.674 1221530959233674641408.000 191510530529933328384.000
# 0          0.601                      0.769                     0.862
# 0          0.464                      0.522                     0.398
#
#    R2 Train All                   R2 CV All                R2 Test All  \
# 0         0.810                       0.701                      0.727
# 0         0.928                    -366.676                    -48.116
# 0         0.465                       0.515                      0.475
# 0         0.736                       0.649                      0.685
# 0         0.651                       0.615                      0.628
# 0         0.706                       0.386                      0.410
# 0         0.500                       0.577                      0.595
# 0         0.549                       0.497                      0.573
# 0         0.739                       0.707                      0.738
# 0         0.500 -1054095811220819935232.000 -132512278207059034112.000
# 0         0.559                       0.443                      0.391
# 0         0.670                       0.602                      0.699
#
#    EV Train All                   EV CV All                EV Test All
# 0         0.810                       0.709                      0.727
# 0         0.928                    -357.361                    -47.862
# 0         0.465                       0.549                      0.495
# 0         0.738                       0.654                      0.688
# 0         0.651                       0.625                      0.632
# 0         0.706                       0.410                      0.422
# 0         0.500                       0.601                      0.603
# 0         0.554                       0.581                      0.595
# 0         0.739                       0.715                      0.738
# 0         0.500 -1027743415940929945600.000 -131836195154917621760.000
# 0         0.559                       0.449                      0.407
# 0         0.673                       0.611                      0.700
